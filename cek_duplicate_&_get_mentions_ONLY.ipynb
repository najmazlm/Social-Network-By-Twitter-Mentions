# %%
import pandas as pd

# Misalkan Anda telah memuat DataFrame Anda, atau Anda dapat menggantinya dengan cara yang sesuai
df = pd.read_excel("theerastour1.xlsx")
df
# Out:
#                           created_at               id_str  \
# 0     Mon Oct 30 23:52:08 +0000 2023  1719140157696160000
# 1     Mon Oct 30 23:01:43 +0000 2023  1719127472363460096
# 2     Mon Oct 30 22:09:36 +0000 2023  1719114354002360064
# 3     Mon Oct 30 22:05:40 +0000 2023  1719113366633900032
# 4     Mon Oct 30 22:00:56 +0000 2023  1719112175988410112
# ...                              ...                  ...
# 9159  Wed Nov 15 08:52:01 +0000 2023  1724711842038060032
# 9160  Wed Nov 15 08:51:40 +0000 2023  1724711752401880064
# 9161  Wed Nov 15 08:50:32 +0000 2023  1724711468891790080
# 9162  Wed Nov 15 08:48:22 +0000 2023  1724710923305100032
# 9163  Wed Nov 15 08:48:18 +0000 2023  1724710907786190080
#
#                                               full_text  quote_count  \
# 0     Tickets for Taylor Swiftâ€™s â€˜Eras Tourâ€™ f...            8
# 1              do you think they saw the eras tour film            0
# 2     Ariana is charting 0 albums on hot 200 as of t...            2
# 3     the eras tour is back next week!!!ðŸ¥° https:/...            8
# 4     my version of the eras tour movie was seeing g...            4
# ...                                                 ...          ...
# 9159  Swifties being weird and obsessed about trying...            0
# 9160  Pero what if sa Philippines gid man ma closing...            0
# 9161                             @deartaylorw Segui amg            0
# 9162                 desayuno en 2 minutos literalmente            0
# 9163  I need a code for the presale of the Eras Tour...            0
#
#       reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              13            137            1608   en  1020011472301309952
# 1               1              0              56   en  1338963828785210112
# 2               9             12             308   en  1559221235443190016
# 3               7             94            1246   en  1197603644100790016
# 4               3             25             625   en  1253609248891820032
# ...           ...            ...             ...  ...                  ...
# 9159            1              0               0   en  1356314784648590080
# 9160            0              0               0   en             65846136
# 9161            0              0               0   pt   907938469787442944
# 9162            0              0               0   es  1293181067378129920
# 9163            5              0               2   es  1707666366356999936
#
#       conversation_id_str         username  \
# 0     1719140157696160000    TSTheErasTour
# 1     1719127472363460096    myhonestfface
# 2     1719114354002360064     kalisredmoon
# 3     1719113366633900032  janesreputation
# 4     1719112175988410112     ellieebraash
# ...                   ...              ...
# 9159  1724711842038060032   swiftswisteria
# 9160  1724711752401880064   michaeldawatan
# 9161  1724563238442939904      ilytholland
# 9162  1724710923305100032      yaopicotres
# 9163  1724710907786190080       paucariide
#
#                                               tweet_url
# 0     https://twitter.com/TSTheErasTour/status/17191...
# 1     https://twitter.com/myhonestfface/status/17191...
# 2     https://twitter.com/kalisredmoon/status/171911...
# 3     https://twitter.com/janesreputation/status/171...
# 4     https://twitter.com/ellieebraash/status/171911...
# ...                                                 ...
# 9159  https://twitter.com/swiftswisteria/status/1724...
# 9160  https://twitter.com/michaeldawatan/status/1724...
# 9161  https://twitter.com/ilytholland/status/1724711...
# 9162  https://twitter.com/yaopicotres/status/1724710...
# 9163  https://twitter.com/paucariide/status/17247109...
#
# [9164 rows x 12 columns]

# %%
# Drop duplicates based on 'text_column'
df_no_duplicates = df.drop_duplicates(subset='full_text')

# Display the result
df_no_duplicates
# Out:
#                           created_at               id_str  \
# 0     Mon Oct 30 23:52:08 +0000 2023  1719140157696160000
# 1     Mon Oct 30 23:01:43 +0000 2023  1719127472363460096
# 2     Mon Oct 30 22:09:36 +0000 2023  1719114354002360064
# 3     Mon Oct 30 22:05:40 +0000 2023  1719113366633900032
# 4     Mon Oct 30 22:00:56 +0000 2023  1719112175988410112
# ...                              ...                  ...
# 8687  Wed Nov 15 11:02:03 +0000 2023  1724744565897210112
# 8688  Wed Nov 15 11:02:01 +0000 2023  1724744556606789888
# 9134  Wed Nov 15 09:04:16 +0000 2023  1724714923559990016
# 9135  Wed Nov 15 09:03:59 +0000 2023  1724714853544130048
# 9136  Wed Nov 15 09:03:58 +0000 2023  1724714848792240128
#
#                                               full_text  quote_count  \
# 0     Tickets for Taylor Swiftâ€™s â€˜Eras Tourâ€™ f...            8
# 1              do you think they saw the eras tour film            0
# 2     Ariana is charting 0 albums on hot 200 as of t...            2
# 3     the eras tour is back next week!!!ðŸ¥° https:/...            8
# 4     my version of the eras tour movie was seeing g...            4
# ...                                                 ...          ...
# 8687  @scaglibeee Foto no super zoom realmente deixa...            0
# 8688  15 anos que usamos o termo cotada para qualque...            0
# 9134  @scarletwest_ Que le den al Madrid por una vez...            0
# 9135  Manas tem 16 pessoas no meu voo indo pra o sho...            0
# 9136  @justaumm à¸­à¸²à¸ˆà¸ˆà¸°à¹€à¸«à¸¡à¸·à¸­à¸™à¸‚...            0
#
#       reply_count  retweet_count  favorite_count lang          user_id_str  \
# 0              13            137            1608   en  1020011472301309952
# 1               1              0              56   en  1338963828785210112
# 2               9             12             308   en  1559221235443190016
# 3               7             94            1246   en  1197603644100790016
# 4               3             25             625   en  1253609248891820032
# ...           ...            ...             ...  ...                  ...
# 8687            1              0               0   pt  1378171277429639936
# 8688            0              0               5   pt           2677929584
# 9134            0              0               0   es   786995141680692992
# 9135            0              0               0   pt  1001654804270269952
# 9136            0              0               0   th           1303857776
#
#       conversation_id_str         username  \
# 0     1719140157696160000    TSTheErasTour
# 1     1719127472363460096    myhonestfface
# 2     1719114354002360064     kalisredmoon
# 3     1719113366633900032  janesreputation
# 4     1719112175988410112     ellieebraash
# ...                   ...              ...
# 8687  1724741939390550016      _Mary_Dale_
# 8688  1724744556606789888     midnighteuss
# 9134  1724369358518960128  whyshedisappred
# 9135  1724714853544130048     oieusousaulo
# 9136  1724663853643150080         2762_KID
#
#                                               tweet_url
# 0     https://twitter.com/TSTheErasTour/status/17191...
# 1     https://twitter.com/myhonestfface/status/17191...
# 2     https://twitter.com/kalisredmoon/status/171911...
# 3     https://twitter.com/janesreputation/status/171...
# 4     https://twitter.com/ellieebraash/status/171911...
# ...                                                 ...
# 8687  https://twitter.com/_Mary_Dale_/status/1724744...
# 8688  https://twitter.com/midnighteuss/status/172474...
# 9134  https://twitter.com/whyshedisappred/status/172...
# 9135  https://twitter.com/oieusousaulo/status/172471...
# 9136  https://twitter.com/2762_KID/status/1724714848...
#
# [5363 rows x 12 columns]

# %%
# Mencari baris yang berisi mention (@)
mention_condition = df_no_duplicates['full_text'].str.contains('@', case=False)  # case=False untuk memperlakukan huruf besar dan kecil sama

# Membuat DataFrame baru hanya dengan baris yang memenuhi kondisi mention
df_with_mention = df_no_duplicates[mention_condition]
df_with_mention
# Out:
#                           created_at               id_str  \
# 13    Mon Oct 30 18:45:36 +0000 2023  1719063016862520064
# 14    Mon Oct 30 18:28:20 +0000 2023  1719058671940890112
# 15    Mon Oct 30 18:26:49 +0000 2023  1719058291181890048
# 18    Mon Oct 30 17:54:23 +0000 2023  1719050125958309888
# 20    Mon Oct 30 12:28:58 +0000 2023  1718968234009819904
# ...                              ...                  ...
# 8680  Wed Nov 15 11:03:02 +0000 2023  1724744813352790016
# 8682  Wed Nov 15 11:02:39 +0000 2023  1724744718989339904
# 8687  Wed Nov 15 11:02:03 +0000 2023  1724744565897210112
# 9134  Wed Nov 15 09:04:16 +0000 2023  1724714923559990016
# 9136  Wed Nov 15 09:03:58 +0000 2023  1724714848792240128
#
#                                               full_text  quote_count  \
# 13    @JohnBraunwarth @xxwntrxx @PopBase Perhaps itâ...            0
# 14    @mtilmann @hushmirrorball She woul let them ow...            0
# 15          @folkIegends That 10 min ballad oh my gawd-            0
# 18    @ChartsDuaLipa @DUALIPA not this again ðŸ’€ðŸ’...            0
# 20    @updateswiftbr My honest reaction: https://t.c...            0
# ...                                                 ...          ...
# 8680                                    @brekkersansa .            0
# 8682                      @callmemarti SIIIIIIIM AMOOOO            0
# 8687  @scaglibeee Foto no super zoom realmente deixa...            0
# 9134  @scarletwest_ Que le den al Madrid por una vez...            0
# 9136  @justaumm à¸­à¸²à¸ˆà¸ˆà¸°à¹€à¸«à¸¡à¸·à¸­à¸™à¸‚...            0
#
#       reply_count  retweet_count  favorite_count lang          user_id_str  \
# 13              1              3              65   en            101118493
# 14              0              2              81   en  1450888676670680064
# 15              0              0              68   en   995064166477155968
# 18              0              0              54   en   995064166477155968
# 20              0             15             250   en   798013701634801024
# ...           ...            ...             ...  ...                  ...
# 8680            1              0               0  qam            276510455
# 8682            0              0               0   pt            421180081
# 8687            1              0               0   pt  1378171277429639936
# 9134            0              0               0   es   786995141680692992
# 9136            0              0               0   th           1303857776
#
#       conversation_id_str         username  \
# 13    1719016671044610048       DJFate1200
# 14    1719011402642240000         Nami_501
# 15    1719057021566149888   tayyoncebutera
# 18    1719049718909570048   tayyoncebutera
# 20    1718967869063450112    mirrorballjao
# ...                   ...              ...
# 8680  1724586055607699968   ladymariastark
# 8682  1724741999524270080  tayIIorswifft13
# 8687  1724741939390550016      _Mary_Dale_
# 9134  1724369358518960128  whyshedisappred
# 9136  1724663853643150080         2762_KID
#
#                                               tweet_url
# 13    https://twitter.com/DJFate1200/status/17190630...
# 14    https://twitter.com/Nami_501/status/1719058671...
# 15    https://twitter.com/tayyoncebutera/status/1719...
# 18    https://twitter.com/tayyoncebutera/status/1719...
# 20    https://twitter.com/mirrorballjao/status/17189...
# ...                                                 ...
# 8680  https://twitter.com/ladymariastark/status/1724...
# 8682  https://twitter.com/tayIIorswifft13/status/172...
# 8687  https://twitter.com/_Mary_Dale_/status/1724744...
# 9134  https://twitter.com/whyshedisappred/status/172...
# 9136  https://twitter.com/2762_KID/status/1724714848...
#
# [1958 rows x 12 columns]

# %%
def onlyMention(text):
  words = text.split()
  Mentions = [word for word in words if '@' in word]
  return ' '.join(Mentions)

#df = pd.read_excel('eras only mention.xlsx')
df_with_mention['full_text'] = df_with_mention['full_text'].apply(onlyMention)
df_with_mention
#df_with_mention.to_excel('eras mention.xlsx')
# Out:
# <ipython-input-5-16e1d51699f9>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_with_mention['full_text'] = df_with_mention['full_text'].apply(onlyMention)
#                           created_at               id_str  \
# 13    Mon Oct 30 18:45:36 +0000 2023  1719063016862520064
# 14    Mon Oct 30 18:28:20 +0000 2023  1719058671940890112
# 15    Mon Oct 30 18:26:49 +0000 2023  1719058291181890048
# 18    Mon Oct 30 17:54:23 +0000 2023  1719050125958309888
# 20    Mon Oct 30 12:28:58 +0000 2023  1718968234009819904
# ...                              ...                  ...
# 8680  Wed Nov 15 11:03:02 +0000 2023  1724744813352790016
# 8682  Wed Nov 15 11:02:39 +0000 2023  1724744718989339904
# 8687  Wed Nov 15 11:02:03 +0000 2023  1724744565897210112
# 9134  Wed Nov 15 09:04:16 +0000 2023  1724714923559990016
# 9136  Wed Nov 15 09:03:58 +0000 2023  1724714848792240128
#
#                                full_text  quote_count  reply_count  \
# 13    @JohnBraunwarth @xxwntrxx @PopBase            0            1
# 14             @mtilmann @hushmirrorball            0            0
# 15                          @folkIegends            0            0
# 18               @ChartsDuaLipa @DUALIPA            0            0
# 20                        @updateswiftbr            0            0
# ...                                  ...          ...          ...
# 8680                       @brekkersansa            0            1
# 8682                        @callmemarti            0            0
# 8687                         @scaglibeee            0            1
# 9134                       @scarletwest_            0            0
# 9136                           @justaumm            0            0
#
#       retweet_count  favorite_count lang          user_id_str  \
# 13                3              65   en            101118493
# 14                2              81   en  1450888676670680064
# 15                0              68   en   995064166477155968
# 18                0              54   en   995064166477155968
# 20               15             250   en   798013701634801024
# ...             ...             ...  ...                  ...
# 8680              0               0  qam            276510455
# 8682              0               0   pt            421180081
# 8687              0               0   pt  1378171277429639936
# 9134              0               0   es   786995141680692992
# 9136              0               0   th           1303857776
#
#       conversation_id_str         username  \
# 13    1719016671044610048       DJFate1200
# 14    1719011402642240000         Nami_501
# 15    1719057021566149888   tayyoncebutera
# 18    1719049718909570048   tayyoncebutera
# 20    1718967869063450112    mirrorballjao
# ...                   ...              ...
# 8680  1724586055607699968   ladymariastark
# 8682  1724741999524270080  tayIIorswifft13
# 8687  1724741939390550016      _Mary_Dale_
# 9134  1724369358518960128  whyshedisappred
# 9136  1724663853643150080         2762_KID
#
#                                               tweet_url
# 13    https://twitter.com/DJFate1200/status/17190630...
# 14    https://twitter.com/Nami_501/status/1719058671...
# 15    https://twitter.com/tayyoncebutera/status/1719...
# 18    https://twitter.com/tayyoncebutera/status/1719...
# 20    https://twitter.com/mirrorballjao/status/17189...
# ...                                                 ...
# 8680  https://twitter.com/ladymariastark/status/1724...
# 8682  https://twitter.com/tayIIorswifft13/status/172...
# 8687  https://twitter.com/_Mary_Dale_/status/1724744...
# 9134  https://twitter.com/whyshedisappred/status/172...
# 9136  https://twitter.com/2762_KID/status/1724714848...
#
# [1958 rows x 12 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame and 'full_text' is the column containing text
df = pd.read_excel("eras mention3.xlsx")

# Define a function to split the text into separate cells
def split_text(text):
    return text.split()

# Apply the split_text function to the 'full_text' column
split_words = df['full_text'].apply(split_text)

# Create a new DataFrame with the separate words and the index of the original DataFrame
new_df = pd.DataFrame(split_words.tolist(), index=split_words.index).stack().reset_index(level=1, drop=True)

# Concatenate the original DataFrame with the new DataFrame
df_split = pd.concat([df.drop('full_text', axis=1), new_df], axis=1)


# Display the result
df_split
#df_split.to_excel('mention theeras.xlsx')
# Out:
#       Unnamed: 0                      created_at               id_str  \
# 0             13  Mon Oct 30 18:45:36 +0000 2023  1719063016862520064
# 0             13  Mon Oct 30 18:45:36 +0000 2023  1719063016862520064
# 0             13  Mon Oct 30 18:45:36 +0000 2023  1719063016862520064
# 1             14  Mon Oct 30 18:28:20 +0000 2023  1719058671940890112
# 1             14  Mon Oct 30 18:28:20 +0000 2023  1719058671940890112
# ...          ...                             ...                  ...
# 1953        8680  Wed Nov 15 11:03:02 +0000 2023  1724744813352790016
# 1954        8682  Wed Nov 15 11:02:39 +0000 2023  1724744718989339904
# 1955        8687  Wed Nov 15 11:02:03 +0000 2023  1724744565897210112
# 1956        9134  Wed Nov 15 09:04:16 +0000 2023  1724714923559990016
# 1957        9136  Wed Nov 15 09:03:58 +0000 2023  1724714848792240128
#
#       quote_count  reply_count  retweet_count  favorite_count lang  \
# 0               0            1              3              65   en
# 0               0            1              3              65   en
# 0               0            1              3              65   en
# 1               0            0              2              81   en
# 1               0            0              2              81   en
# ...           ...          ...            ...             ...  ...
# 1953            0            1              0               0  qam
# 1954            0            0              0               0   pt
# 1955            0            1              0               0   pt
# 1956            0            0              0               0   es
# 1957            0            0              0               0   th
#
#               user_id_str  conversation_id_str         username  \
# 0               101118493  1719016671044610048       DJFate1200
# 0               101118493  1719016671044610048       DJFate1200
# 0               101118493  1719016671044610048       DJFate1200
# 1     1450888676670680064  1719011402642240000         Nami_501
# 1     1450888676670680064  1719011402642240000         Nami_501
# ...                   ...                  ...              ...
# 1953            276510455  1724586055607699968   ladymariastark
# 1954            421180081  1724741999524270080  tayIIorswifft13
# 1955  1378171277429639936  1724741939390550016      _Mary_Dale_
# 1956   786995141680692992  1724369358518960128  whyshedisappred
# 1957           1303857776  1724663853643150080         2762_KID
#
#                                               tweet_url                0
# 0     https://twitter.com/DJFate1200/status/17190630...  @JohnBraunwarth
# 0     https://twitter.com/DJFate1200/status/17190630...        @xxwntrxx
# 0     https://twitter.com/DJFate1200/status/17190630...         @PopBase
# 1     https://twitter.com/Nami_501/status/1719058671...        @mtilmann
# 1     https://twitter.com/Nami_501/status/1719058671...  @hushmirrorball
# ...                                                 ...              ...
# 1953  https://twitter.com/ladymariastark/status/1724...    @brekkersansa
# 1954  https://twitter.com/tayIIorswifft13/status/172...     @callmemarti
# 1955  https://twitter.com/_Mary_Dale_/status/1724744...      @scaglibeee
# 1956  https://twitter.com/whyshedisappred/status/172...    @scarletwest_
# 1957  https://twitter.com/2762_KID/status/1724714848...        @justaumm
#
# [2389 rows x 13 columns]

# %%
df = pd.read_excel("mention theeras clean.xlsx")

# Remove the @ symbol from the 'text_column'
df['mention'] = df['mention'].replace('@', '', regex=True)
df
df.to_excel('mention theeras clean2.xlsx')
